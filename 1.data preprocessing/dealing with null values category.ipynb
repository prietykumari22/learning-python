# %%
#dealing of null values with category

import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer ##importing simple imputer function from sllearn
imputer = SimpleImputer(missing_values = np.nan,strategy='most_frequent')

# %%
df = pd.read_csv('googleplaystore.csv')  ## loaded the data

# %%
df.drop(['Last Updated','Current Ver','Android Ver'],axis = 1,inplace=True)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# dtype: int64

# %%
rating = np.reshape(df['Rating'].values,  (10841,1))

# %%
imputer.fit(rating)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
df.iloc[ : , 2: 3] =imputer.transform(rating)

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# dtype: int64

# %%
df #after using startegy ='most_frequent' and printing df we are getting the value of rating in the format we want and earlier 
    #printing df is giving another value when we are using starategy to 'mean'
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ###### rating value are generally in either 1.0,1.1,1.2  is of length 3  one prefix ,period then post -fix but  in the above dataframe  we are having value i.e 4.99338 which is not of our use these value should be 4.9 , 4.1 and fot 4.193338 it is either 4.2 or 4.1 if we want to find average we can use mean but mean will not work here we need to go dig deeper into it
#     in startegy by default it is mean ,what are the other option what else we have "MEDIAN","MOST_FREQUENT","CONSTANT"
#     CONSTANT :-then replace missing values with fill_value.can be used with strings or numeric data

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# dtype: int64

# %%
df['Type']
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 10841, dtype: object

# %%
# we are having null value for type and content rating 
type_ty = np.reshape(df['Type'].values,  (10841,1)) #prrified the most frequent value and fill the value at the nan place 
imputer.fit(type_ty)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
df.iloc[ : , 6: 7] =imputer.transform(type_ty)

# %%
df.isnull().sum() #the null value is repleced with some most frequent value
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# dtype: int64

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Content Rating']
# Out:
# 0          Everyone
# 1          Everyone
# 2          Everyone
# 3              Teen
# 4          Everyone
#             ...
# 10836      Everyone
# 10837      Everyone
# 10838      Everyone
# 10839    Mature 17+
# 10840      Everyone
# Name: Content Rating, Length: 10841, dtype: object

# %%
content_rating = np.reshape(df['Content Rating'].values,(10841,1))
imputer.fit(content_rating)
df.iloc[ : , 8: 9] =imputer.transform(content_rating)

# %% [markdown]
# ######passing data frame will raise up an error because imputer will take a fixed shape ,every function will take a fixed shape. 'IMPUTER'is taking a numpy array it is not taking the datframe that is ywe cannot pass df function that we are having that is y we are using np.reshaping

# %%
df.isnull().sum()  #content rating has not habing any null value
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# dtype: int64

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
