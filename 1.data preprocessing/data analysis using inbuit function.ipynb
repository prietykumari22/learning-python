# %%
#using inbuilt function 
import pandas as pd
import numpy as np
import matplotlib.pyplot as pld

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df.drop(['Last Updated','Current Ver','Android Ver'],axis = 1,inplace=True)

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres
# 0               Art & Design
# 1  Art & Design;Pretend Play
# 2               Art & Design
# 3               Art & Design
# ...

# %%
df[df['Category'] == 'ART_AND_DESIGN']['Type'] =='Free'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 5258    True
# 6930    True
# 8679    True
# 8712    True
# 8888    True
# Name: Type, Length: 62, dtype: bool

# %%
df[df['Category'] == 'ART_AND_DESIGN']
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 5258  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper  ART_AND_DESIGN
# 6930               Fantasy theme dark bw black building  ART_AND_DESIGN
# 8679                                       Dp for girls  ART_AND_DESIGN
# 8712             Name Art DP - Focus n Filter Text 2018  ART_AND_DESIGN
# 8888            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#       Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
#here we are framing the data based on categeory ,type and content rating
temp=df[df['Category']=='FAMILY']
temp=temp[temp['Type']=='Paid']
temp=temp[temp['Content Rating']=='Everyone']

# %%
temp
# Out:
#                                 App Category  Rating Reviews  \
# 2062             Toca Mystery House   FAMILY     4.2      96
# 2085    My Little Princess : Stores   FAMILY     4.3     169
# 2086             Sago Mini Big City   FAMILY     4.2       8
# 2087             Pinkalicious Party   FAMILY     3.0       2
# 2150                  Toca Builders   FAMILY     4.2    3328
# ...                             ...      ...     ...     ...
# 9541                       El Chavo   FAMILY     4.0     751
# 9678              Where's My Water?   FAMILY     4.7  188740
# 9690   Out There Chronicles - Ep. 1   FAMILY     4.4    1516
# 10459                     SCI-FI UI   FAMILY     4.7      15
# 10785                  sugar, sugar   FAMILY     4.2    1405
#
#                      Size    Installs  Type  Price Content Rating  \
# 2062                  79M      5,000+  Paid  $3.99       Everyone
# 2085                  60M      5,000+  Paid  $2.99       Everyone
# ...

# %% [markdown]
# #sorting above temp datframe according to ascending order of reviews
# temp.sort_values(by='Reviews',ascending = True)

# %%
#sorting above temp datframe according to ascending order 
temp.sort_values(by='Reviews',ascending = True).head(10) #to be more specific we have a lot of parameter
# Out:
#                                                     App Category  Rating  \
# 5978                      Truck Driving Test Class 3 BC   FAMILY     1.0
# 5246                              Hey AJ! It's Bedtime!   FAMILY     5.0
# 7204          TI-84 CE Graphing Calculator Manual TI 84   FAMILY     5.0
# 5482                         meStudying: AP English Lit   FAMILY     5.0
# 7477                         USMLE Step 2 CK Flashcards   FAMILY     5.0
# 4127                                  Speech Therapy: F   FAMILY     1.0
# 8018  30WPM Amateur ham radio Koch CW Morse code tra...   FAMILY     5.0
# 5479                                   iScore5 AP Psych   FAMILY     2.9
# 8371                                     ZombieVital DG   FAMILY     4.3
# 6570                                    Bo's School Day   FAMILY     4.7
#
#      Reviews  Size Installs  Type   Price Content Rating  \
# 5978       1  2.0M      50+  Paid   $1.49       Everyone
# ...

# %%
df.groupby('Category').mean()['Rating'].sort_values(ascending= False).plot.bar()##making the group with respect to ratimg
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
df.sort_values(by='Reviews',ascending = False).head(10) #to be more specific we have a lot of parameter
# Out:
#                                                     App          Category  \
# 2989                             GollerCepte Live Score            SPORTS
# 4970                       Ad Block REMOVER - NEED ROOT             TOOLS
# 2723                                SnipSnap Coupon App          SHOPPING
# 2705                                SnipSnap Coupon App          SHOPPING
# 3079                  US Open Tennis Championships 2018            SPORTS
# 3229                                         DreamTrips  TRAVEL_AND_LOCAL
# 3049                  US Open Tennis Championships 2018            SPORTS
# 7002   Adult Color by Number Book - Paint Mandala Pages            FAMILY
# 6724                     BSPlayer ARMv7 VFP CPU support     VIDEO_PLAYERS
# 7982  Easy Resume Builder, Resume help, Curriculum v...             TOOLS
#
#       Rating Reviews                Size    Installs  Type Price  \
# 2989     4.2    9992                 31M  1,000,000+  Free     0
# ...

# %%
df['Reviews'].values
# Out:
# array(['159', '967', '87510', ..., '4', '114', '398307'], dtype=object)

# %%
df['Reviews']=np.array(df['Reviews'].values, dtype = int) #values are in integer format

# %%
 
df.sort_values(by='Reviews',ascending = False).head(10)
# Out:
#                                            App       Category  Rating  \
# 2544                                  Facebook         SOCIAL     4.1
# 3943                                  Facebook         SOCIAL     4.1
# 381                         WhatsApp Messenger  COMMUNICATION     4.4
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 3904                        WhatsApp Messenger  COMMUNICATION     4.4
# 2604                                 Instagram         SOCIAL     4.5
# 2611                                 Instagram         SOCIAL     4.5
# 2545                                 Instagram         SOCIAL     4.5
# 3909                                 Instagram         SOCIAL     4.5
# 382   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
#
#        Reviews                Size        Installs  Type Price Content Rating  \
# 2544  78158306  Varies with device  1,000,000,000+  Free     0           Teen
# ...

# %%
df.sort_values(by='Reviews',ascending = False).head(10)['App'].unique()
# Out:
# array(['Facebook', 'WhatsApp Messenger', 'Instagram',
#        'Messenger – Text and Video Chat for Free'], dtype=object)
